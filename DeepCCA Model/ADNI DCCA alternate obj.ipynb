# %% [markdown]
# # Testing DCCA with different objective function

# %% [markdown]
# ## Importing stuff:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import torch
import torch.nn as nn
from linear_cca import linear_cca
from torch.utils.data import BatchSampler, SequentialSampler
from DeepCCAModels import DeepCCA
from main import Solver
from utils import load_data, svm_classify
from objectives import cca_loss
try:
    import cPickle as thepickle
except ImportError:
    import _pickle as thepickle
from IPython.display import display
import pickle
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import sklearn.model_selection as model_selection
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import pprint
from sklearn import preprocessing

# %% [markdown]
# ## Reading the data:

# %%
unique = pd.read_pickle("./DATA/Linearly_Transformed_Unique_Dataset.pkl")
print(unique.shape)
unique.head(10)
# Out:
# (1302, 209)
#           PTID                   MRID        Date        Age  Sex  \
# 0   002_S_0295  002_S_0295_2006-04-18  2006-04-18  84.742466    0
# 9   002_S_0413  002_S_0413_2006-05-02  2006-05-02  76.283562    1
# 24  002_S_0559  002_S_0559_2006-05-23  2006-05-23  79.223288    0
# 31  002_S_0619  002_S_0619_2006-06-01  2006-06-01  77.447945    0
# 45  002_S_0729  002_S_0729_2006-07-17  2006-07-17  65.056164    1
# 64  002_S_0816  002_S_0816_2006-08-30  2006-08-30  70.767123    0
# 69  002_S_0938  002_S_0938_2006-10-05  2006-10-05  82.167123    1
# 74  002_S_0954  002_S_0954_2006-10-10  2006-10-10  69.198630    1
# 81  002_S_0955  002_S_0955_2006-10-11  2006-10-11  78.161644    1
# 84  002_S_1018  002_S_1018_2006-11-29  2006-11-29  70.658904    1
#
#     DLICV_baseline  APOE4_Alleles APOE_Genotype Diagnosis_nearest_2.0  \
# 0      1485405.375            1.0         E3/E4                    CN
# 9      1364116.000            0.0         E3/E3                    CN
# 24     1570479.625            1.0         E3/E4                    CN
# 31     1859348.250            2.0         E4/E4              Dementia
# 45     1166961.750            1.0         E3/E4                   MCI
# 64     1444128.125            2.0         E4/E4              Dementia
# 69     1309685.000            0.0         E3/E3              Dementia
# 74     1075661.500            1.0         E3/E4                   MCI
# 81     1363607.000            1.0         E3/E4              Dementia
# 84     1355603.000            0.0         E3/E3              Dementia
#
#     MUSE_Volume_4  ...  rs111278892  rs3752246  rs4147929  rs41289512  \
# 0     -401.428503  ...            1          1          1           0
# 9      596.355045  ...            0          1          1           0
# 24     224.874560  ...            0          0          0           0
# 31    2633.277779  ...            0          0          0           1
# 45     256.289641  ...            0          0          0           1
# 64    -126.260419  ...            0          0          0           0
# 69     200.102369  ...            0          1          1           0
# 74     -60.539913  ...            2          1          1           0
# 81    1058.028132  ...            1          0          0           0
# 84    -485.048304  ...            1          1          1           0
#
#     rs3865444  rs6024870  rs6014724  rs7274581  rs429358  \
# 0           0          0          0          0         1
# 9           1          0          0          0         0
# 24          1          0          0          0         0
# 31          1          0          0          0         2
# 45          1          0          0          0         1
# 64          1          0          0          0         2
# 69          1          0          0          0         0
# 74          1          0          0          0         1
# 81          1          0          0          0         1
# 84          0          0          0          0         0
#
#     Diagnosis_nearest_2.0_cat
# 0                           0
# 9                           0
# 24                          0
# 31                          1
# 45                          2
# 64                          1
# 69                          1
# 74                          2
# 81                          1
# 84                          1
#
# [10 rows x 209 columns]

# %% [markdown]
# ### Scaling the data:

# %% [markdown]
# This is needed for SKL CCA objective function to function properly:

# %%
# Scale the data:
scaler = preprocessing.StandardScaler()
c = list(unique.columns)
MRI_columns = c[c.index("MUSE_Volume_4"):c.index("MUSE_Volume_207")+1]
unique_scaled = scaler.fit_transform(unique[MRI_columns])
unique[MRI_columns] = unique_scaled
unique.head(10)
# Out:
#           PTID                   MRID        Date        Age  Sex  \
# 0   002_S_0295  002_S_0295_2006-04-18  2006-04-18  84.742466    0
# 9   002_S_0413  002_S_0413_2006-05-02  2006-05-02  76.283562    1
# 24  002_S_0559  002_S_0559_2006-05-23  2006-05-23  79.223288    0
# 31  002_S_0619  002_S_0619_2006-06-01  2006-06-01  77.447945    0
# 45  002_S_0729  002_S_0729_2006-07-17  2006-07-17  65.056164    1
# 64  002_S_0816  002_S_0816_2006-08-30  2006-08-30  70.767123    0
# 69  002_S_0938  002_S_0938_2006-10-05  2006-10-05  82.167123    1
# 74  002_S_0954  002_S_0954_2006-10-10  2006-10-10  69.198630    1
# 81  002_S_0955  002_S_0955_2006-10-11  2006-10-11  78.161644    1
# 84  002_S_1018  002_S_1018_2006-11-29  2006-11-29  70.658904    1
#
#     DLICV_baseline  APOE4_Alleles APOE_Genotype Diagnosis_nearest_2.0  \
# 0      1485405.375            1.0         E3/E4                    CN
# 9      1364116.000            0.0         E3/E3                    CN
# 24     1570479.625            1.0         E3/E4                    CN
# 31     1859348.250            2.0         E4/E4              Dementia
# 45     1166961.750            1.0         E3/E4                   MCI
# 64     1444128.125            2.0         E4/E4              Dementia
# 69     1309685.000            0.0         E3/E3              Dementia
# 74     1075661.500            1.0         E3/E4                   MCI
# 81     1363607.000            1.0         E3/E4              Dementia
# 84     1355603.000            0.0         E3/E3              Dementia
#
#     MUSE_Volume_4  ...  rs111278892  rs3752246  rs4147929  rs41289512  \
# 0       -0.854457  ...            1          1          1           0
# 9        0.712451  ...            0          1          1           0
# 24       0.129082  ...            0          0          0           0
# 31       3.911211  ...            0          0          0           1
# 45       0.178416  ...            0          0          0           1
# 64      -0.422337  ...            0          0          0           0
# 69       0.090180  ...            0          1          1           0
# 74      -0.319130  ...            2          1          1           0
# 81       1.437457  ...            1          0          0           0
# 84      -0.985773  ...            1          1          1           0
#
#     rs3865444  rs6024870  rs6014724  rs7274581  rs429358  \
# 0           0          0          0          0         1
# 9           1          0          0          0         0
# 24          1          0          0          0         0
# 31          1          0          0          0         2
# 45          1          0          0          0         1
# 64          1          0          0          0         2
# 69          1          0          0          0         0
# 74          1          0          0          0         1
# 81          1          0          0          0         1
# 84          0          0          0          0         0
#
#     Diagnosis_nearest_2.0_cat
# 0                           0
# 9                           0
# 24                          0
# 31                          1
# 45                          2
# 64                          1
# 69                          1
# 74                          2
# 81                          1
# 84                          1
#
# [10 rows x 209 columns]

# %% [markdown]
# ### Check for NaN values:

# %%
unique.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Building the Model:

# %%
# Standard parameters that shouldn't be changed:
device = torch.device('cpu')
outdim_size = 145
input_shape1 = 145 # view_1.shape[1]
input_shape2 = 54  # view_2.shape[2]
layer_sizes1 = [25, 100, 100, outdim_size]
layer_sizes2 = [25, 100, 100, outdim_size]
learning_rate = 1e-4
epoch_num = 100
epoch_log_freq = 1
batch_size = 1000
reg_par = 1e-3
use_all_singular_values = False
l_cca = linear_cca()

# Data:
view_1 = unique.loc[:,"MUSE_Volume_4":"MUSE_Volume_207"]
view_2 = unique.loc[:,"rs4575098":"rs429358"]
# Convert the pandas dataframe to numpy arrays for pytorch:
view_1_n = view_1.to_numpy()
view_2_n = view_2.to_numpy()
indices = np.arange(view_1_n.shape[0])
# np.random.shuffle(indices)
view_1_n = view_1_n[indices]
view_2_n = view_2_n[indices].astype(np.float64) # DeepCCA MLP requires double type

view_1_t = torch.from_numpy(view_1_n)
view_2_t = torch.from_numpy(view_2_n)

data1 = view_1_t
data2 = view_2_t

model = DeepCCA(layer_sizes1, layer_sizes2, input_shape1, input_shape2, outdim_size, use_all_singular_values, device=device).double()
solver = Solver(model, l_cca, outdim_size, epoch_num, batch_size, learning_rate, reg_par, device=device, epoch_log_freq=epoch_log_freq, log=True)

s_1, s_2 = data1.shape[0], data2.shape[0]
# Split the dataset into training, validation and testing (75%-15%-10%):
train1, train2 = data1[0:int(s_1 * 0.75)], data2[0:int(s_2 * 0.75)]
val1, val2 = data1[int(s_1 * 0.75):int(s_1 * 0.9)], data2[int(s_2 * 0.75):int(s_2 * 0.9)]
test1, test2 = data1[int(s_1 * 0.9):], data2[int(s_2 * 0.9):]
# Out:
# [ INFO : 2022-04-07 09:35:19,462 ] - DataParallel(
#   (module): DeepCCA(
#     (model1): MlpNet(
#       (layers): ModuleList(
#         (0): Sequential(
#           (0): Linear(in_features=145, out_features=25, bias=True)
#           (1): Sigmoid()
#           (2): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (1): Sequential(
#           (0): Linear(in_features=25, out_features=100, bias=True)
#           (1): Sigmoid()
#           (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (2): Sequential(
#           (0): Linear(in_features=100, out_features=100, bias=True)
#           (1): Sigmoid()
#           (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (3): Sequential(
#           (0): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): Linear(in_features=100, out_features=145, bias=True)
#         )
#       )
#     )
#     (model2): MlpNet(
#       (layers): ModuleList(
#         (0): Sequential(
#           (0): Linear(in_features=54, out_features=25, bias=True)
#           (1): Sigmoid()
#           (2): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (1): Sequential(
#           (0): Linear(in_features=25, out_features=100, bias=True)
#           (1): Sigmoid()
#           (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (2): Sequential(
#           (0): Linear(in_features=100, out_features=100, bias=True)
#           (1): Sigmoid()
#           (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (3): Sequential(
#           (0): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): Linear(in_features=100, out_features=145, bias=True)
#         )
#       )
#     )
#   )
# )
# [ INFO : 2022-04-07 09:35:19,463 ] - LBFGS (
# Parameter Group 0
#     history_size: 100
#     line_search_fn: None
#     lr: 1
#     max_eval: 25
#     max_iter: 20
#     tolerance_change: 1e-09
#     tolerance_grad: 1e-07
# )

# %% [markdown]
# ## Training the model:

# %%
loss = solver.fit(train1, train2, val1, val2, test1, test2, checkpoint=None)
training_losses, val_losses = solver.get_losses()
# Out:
# [ INFO : 2022-04-07 09:35:29,879 ] - Epoch 1: val_loss did not improve from 0.0000
# [ INFO : 2022-04-07 09:35:29,879 ] - Epoch 1/100 - time: 9.73 - training_loss: 1.2555 - val_loss: 1.2851
# /opt/homebrew/Caskroom/miniforge/base/envs/Testing/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# [ INFO : 2022-04-07 09:35:39,540 ] - Epoch 2: val_loss did not improve from 0.0000
# [ INFO : 2022-04-07 09:35:39,540 ] - Epoch 2/100 - time: 9.66 - training_loss: 1.2555 - val_loss: 1.1003
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 loss = solver.fit(train1, train2, val1, val2, test1, test2, checkpoint=None)
#       2 training_losses, val_losses = solver.get_losses()
#
# File ~/Desktop/Important Stuff/Dissertation/DeepCCA Model/main.py:106, in Solver.fit(self, x1, x2, vx1, vx2, tx1, tx2, checkpoint)
#     104 with torch.no_grad():
#     105     self.model.eval()
# --> 106     val_loss = self.test(vx1, vx2)
#     107     self.val_losses.append(val_loss)
#     108     info_string += " - val_loss: {:.4f}".format(val_loss)
#
# File ~/Desktop/Important Stuff/Dissertation/DeepCCA Model/main.py:149, in Solver.test(self, x1, x2, use_linear_cca)
#     147 def test(self, x1, x2, use_linear_cca=False):
#     148     with torch.no_grad():
# --> 149         losses, outputs = self._get_outputs(x1, x2)
#     151         if use_linear_cca:
#     152             print("Linear CCA started!")
#
# File ~/Desktop/Important Stuff/Dissertation/DeepCCA Model/main.py:178, in Solver._get_outputs(self, x1, x2)
#     176         outputs1.append(o1)
#     177         outputs2.append(o2)
# --> 178         loss = self.loss(o1, o2)
#     179         losses.append(loss.item())
#     180 outputs = [torch.cat(outputs1, dim=0).cpu().numpy(),
#     181            torch.cat(outputs2, dim=0).cpu().numpy()]
#
# File ~/Desktop/Important Stuff/Dissertation/DeepCCA Model/objectives.py:100, in cca_loss.loss(self, H1, H2)
#      98 n_comps = self.outdim_size//2
#      99 cca = CCA(n_components=n_comps,  max_iter=1000)
# --> 100 cca.fit(H1, H2)
#     101 corr = cca.score(H1,H2)
#     102 l = 1 - corr
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/Testing/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:294, in _PLS.fit(self, X, Y)
#     287 Yk[:, Yk_mask] = 0.0
#     289 try:
#     290     (
#     291         x_weights,
#     292         y_weights,
#     293         n_iter_,
# --> 294     ) = _get_first_singular_vectors_power_method(
#     295         Xk,
#     296         Yk,
#     297         mode=self.mode,
#     298         max_iter=self.max_iter,
#     299         tol=self.tol,
#     300         norm_y_weights=norm_y_weights,
#     301     )
#     302 except StopIteration as e:
#     303     if str(e) != "Y residual is constant":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/Testing/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:79, in _get_first_singular_vectors_power_method(X, Y, mode, max_iter, tol, norm_y_weights)
#      70 x_weights_old = 100  # init to big value for first convergence check
#      72 if mode == "B":
#      73     # Precompute pseudo inverse matrices
#      74     # Basically: X_pinv = (X.T X)^-1 X.T
#    (...)
#      77     # B) will be unstable if n_features > n_samples or n_targets >
#      78     # n_samples
# ---> 79     X_pinv, Y_pinv = _pinv2_old(X), _pinv2_old(Y)
#      81 for i in range(max_iter):
#      82     if mode == "B":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/Testing/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:41, in _pinv2_old(a)
#      35 def _pinv2_old(a):
#      36     # Used previous scipy pinv2 that was updated in:
#      37     # https://github.com/scipy/scipy/pull/10067
#      38     # We can not set `cond` or `rcond` for pinv2 in scipy >= 1.3 to keep the
#      39     # same behavior of pinv2 for scipy < 1.3, because the condition used to
#      40     # determine the rank is dependent on the output of svd.
# ---> 41     u, s, vh = svd(a, full_matrices=False, check_finite=False)
#      43     t = u.dtype.char.lower()
#      44     factor = {"f": 1e3, "d": 1e6}
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/Testing/lib/python3.8/site-packages/scipy/linalg/_decomp_svd.py:131, in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     127 u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
#     128                       full_matrices=full_matrices, overwrite_a=overwrite_a)
#     130 if info > 0:
# --> 131     raise LinAlgError("SVD did not converge")
#     132 if info < 0:
#     133     raise ValueError('illegal value in %dth argument of internal gesdd'
#     134                      % -info)
#
# LinAlgError: SVD did not converge
