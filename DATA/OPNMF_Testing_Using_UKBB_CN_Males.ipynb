# %% [markdown]
# # Testing the OPNMF method
#
# This notebook uses the data available from the UK BioBank database. The data includes 599 Cognitive Normal Males. We use the 145 Regions Of Interest (ROI) that are included, to apply OPNMF and see the optimal number of components.
#
# In a later change, the ROIs will be replaced with the RAVENS maps

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("ukbb_cn_males_baseline_4550.csv")
data.head()
# Out:
#       PTID        Date Visit_Code   Age      Study        Phase  \
# 0  1214962  2015-07-11        2_0  45.0  UKBIOBANK  UKBB-Batch8
# 1  1177941  2014-08-30        2_0  45.0  UKBIOBANK  UKBB-Batch3
# 2  1065888  2016-08-20        2_0  46.0  UKBIOBANK  UKBB-Batch8
# 3  1080555  2015-03-09        2_0  46.0  UKBIOBANK  UKBB-Batch8
# 4  1109805  2016-04-03        2_0  46.0  UKBIOBANK  UKBB-Batch4
#
#    Delta_Baseline  Education_Years APOE_Genotype  APOE4_Alleles  ...  \
# 0          1892.0              NaN         E2/E3            0.0  ...
# 1          1607.0              NaN         E3/E3            0.0  ...
# 2          2227.0              NaN         E3/E3            0.0  ...
# 3          1925.0              NaN           NaN            NaN  ...
# 4          2085.0              NaN         E3/E3            0.0  ...
#
#                                                 WMLS  \
# 0  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 1  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 2  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 3  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 4  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
#
#                                            RAVENS_GM  \
# 0  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 1  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 2  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 3  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 4  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
#
#                                            RAVENS_VN  \
# 0  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 1  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 2  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 3  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 4  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
#
#                                            RAVENS_WM  \
# 0  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 1  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 2  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 3  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 4  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
#
#                                           RAVENS_CSF  \
# 0  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 1  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 2  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 3  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
# 4  /cbica/projects/UKBB_Processed/Pipelines/UKBB_...
#
#                                          H_RAVENS_GM  \
# 0  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 1  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 2  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 3  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 4  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
#
#                                          H_RAVENS_VN  \
# 0  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 1  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 2  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 3  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 4  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
#
#                                          H_RAVENS_WM  \
# 0  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 1  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 2  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 3  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
# 4  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...
#
#                                         H_RAVENS_CSF  session_id
# 0  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...           1
# 1  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...           1
# 2  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...           1
# 3  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...           1
# 4  /cbica/projects/ISTAGING/Pipelines/ISTAGING_Da...           1
#
# [5 rows x 705 columns]

# %% [markdown]
# ### The columns that interest us are the 145 ROIs:
#
# We need essentially the columns MUSE_Volume_4 , ... , MUSE_Volume_207.

# %%
column_list = list(data.columns)
start = column_list.index("MUSE_Volume_4")
end   = column_list.index("MUSE_Volume_207")

roi_matrix = data[ column_list[start:end+1] ]
# Add the PTID for reference:
# roi_matrix = data[ ["PTID"] + column_list[start:end+1]]
roi_matrix.head()
# Out:
#    MUSE_Volume_4  MUSE_Volume_11  MUSE_Volume_23  MUSE_Volume_30  \
# 0    1057.003024     1790.005121      382.001093      358.001024
# 1    1395.006984     2848.014259      550.002754      575.002879
# 2     763.999818     1554.999629      362.999913      361.999914
# 3     632.000753     1230.001466      468.000558      470.000560
# 4     566.000270     1137.000542      468.000223      467.000223
#
#    MUSE_Volume_31  MUSE_Volume_32  MUSE_Volume_35  MUSE_Volume_36  \
# 0      955.002732      987.002824    23171.066293     3175.009084
# 1     1267.006344     1222.006118    26027.130312     4036.020207
# 2     1041.999752     1104.999737    21884.994782     2855.999319
# 3      938.001118      971.001158    22836.027223     3024.003605
# 4     1092.000521     1203.000574    24355.011613     2930.001397
#
#    MUSE_Volume_37  MUSE_Volume_38  ...  MUSE_Volume_198  MUSE_Volume_199  \
# 0     3089.008838    47976.137260  ...      9446.027025     10389.029723
# 1     3790.018976    66299.331945  ...     12556.062865     11597.058064
# 2     2878.999314    55630.986737  ...      8629.997942      9008.997852
# 3     3075.003666    53106.063307  ...      9406.011213      9517.011345
# 4     2913.001389    44892.021406  ...      9209.004391      9116.004347
#
#    MUSE_Volume_200  MUSE_Volume_201  MUSE_Volume_202  MUSE_Volume_203  \
# 0      7161.020488      6581.018828      8594.024588      7765.022216
# 1      7684.038472      9264.046383      9924.049687     10564.052892
# 2      6600.998426      7305.998258     10003.997615      8926.997872
# 3      7208.008593      6852.008168      8861.010563      8875.010580
# 4      7104.003387      8328.003971     10632.005070      8658.004128
#
#    MUSE_Volume_204  MUSE_Volume_205  MUSE_Volume_206  MUSE_Volume_207
# 0      3177.009089      3828.010952      1508.004314      1684.004818
# 1      3113.015586      3225.016147      1391.006964      1389.006954
# 2      3400.999189      3901.999070      1145.999727      1676.999600
# 3      3112.003710      4133.004927      1600.001907      2177.002595
# 4      3219.001535      4058.001935      1561.000744      2289.001091
#
# [5 rows x 145 columns]

# %% [markdown]
# ### Perform OPNMF:
#
# For testing purposes I use sklearn NMF code, later use of lab OPNMF code will be integrated

# %%
from sklearn.decomposition import NMF

model = NMF(n_components=15, init='random', random_state=0, max_iter=5000)
W = model.fit_transform(roi_matrix)
H = model.components_

# %% [markdown]
# ### Visualize the Coefficients:

# %%
coeffs = pd.DataFrame(np.transpose(H),columns = ["Component " + str(i+1) for i in range(model.n_components)])
coeffs.head()
# Out:
#    Component 1  Component 2  Component 3  Component 4  Component 5  \
# 0     0.776989     1.860794     1.666682     0.000000    15.226360
# 1     3.665332     2.087805     0.000000     1.147357    20.860084
# 2     0.888201     0.568438     0.570720     0.270925     2.451631
# 3     1.112495     0.491321     0.555795     0.176266     1.338812
# 4     1.699706     2.493616     1.486436     1.597001    11.326832
#
#    Component 6  Component 7  Component 8  Component 9  Component 10  \
# 0     1.302001    15.229960     3.390230    39.225443      0.000000
# 1     6.763519    32.137167     0.798210   121.307412      4.700305
# 2     0.850116     2.804590     0.542219    49.048022      1.830295
# 3     0.861641     2.828412     0.880270    57.202774      1.527640
# 4     2.456025     9.018586     2.104546   121.955112      3.694008
#
#    Component 11  Component 12  Component 13  Component 14  Component 15
# 0      0.532068      0.000000    554.035960      0.000000      0.000000
# 1      0.000000      0.000000    397.476628      0.000000      0.763711
# 2      0.709402      8.438929      0.000000      1.943963      0.635443
# 3      0.850275     10.848527      0.000000      1.672046      0.763395
# 4      1.467911     18.688976     45.503721      2.461235      1.020032

# %%
H[0].shape
# Out:
# (145,)
